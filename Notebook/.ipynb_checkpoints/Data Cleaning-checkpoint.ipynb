# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/API_BGD.csv')
df.head()
# Out:
#   Country Name Country Code  \
# 0   Bangladesh          BGD
# 1   Bangladesh          BGD
# 2   Bangladesh          BGD
# 3   Bangladesh          BGD
# 4   Bangladesh          BGD
#
#                                       Indicator Name        Indicator Code  \
# 0  Internally displaced persons, new displacement...           VC.IDP.NWDS
# 1  Merchandise exports to low- and middle-income ...     TX.VAL.MRCH.R3.ZS
# 2  Medium and high-tech exports (% manufactured e...     TX.MNF.TECH.ZS.UN
# 3  Merchandise imports from low- and middle-incom...     TM.VAL.MRCH.OR.ZS
# 4  Tariff rate, applied, simple mean, primary pro...  TM.TAX.TCOM.SM.AR.ZS
#
#    1960  1961  1962  1963  1964  1965  ...           2011           2012  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...  400000.000000  651000.000000
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...       1.002362       1.044091
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ...       2.025555       2.130069
# ...

# %%
sdf = df.loc[:,'1960':]
pd.melt(sdf,var_name='year',value_name='value')
# Out:
#        year  value
# 0      1960    NaN
# 1      1960    NaN
# 2      1960    NaN
# 3      1960    NaN
# 4      1960    NaN
# ...     ...    ...
# 87469  2020    NaN
# 87470  2020    NaN
# 87471  2020    NaN
# 87472  2020    NaN
# 87473  2020    NaN
#
# [87474 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
sdf = pd.melt(df,id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
        value_vars=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020'], 
        var_name='year',
        value_name='value')

sdf
# Out:
#       Country Name Country Code  \
# 0       Bangladesh          BGD
# 1       Bangladesh          BGD
# 2       Bangladesh          BGD
# 3       Bangladesh          BGD
# 4       Bangladesh          BGD
# ...            ...          ...
# 87469   Bangladesh          BGD
# 87470   Bangladesh          BGD
# 87471   Bangladesh          BGD
# 87472   Bangladesh          BGD
# 87473   Bangladesh          BGD
#
#                                           Indicator Name  \
# 0      Internally displaced persons, new displacement...
# 1      Merchandise exports to low- and middle-income ...
# 2      Medium and high-tech exports (% manufactured e...
# 3      Merchandise imports from low- and middle-incom...
# 4      Tariff rate, applied, simple mean, primary pro...
# ...                                                  ...
# 87469  Foreign direct investment, net inflows (BoP, c...
# 87470            Net secondary income (BoP, current US$)
# ...

# %%
sdf.drop(['Country Code', 'Indicator Code'],axis=1,inplace=True)
sdf
# Out:
#       Country Name                                     Indicator Name  year  \
# 0       Bangladesh  Internally displaced persons, new displacement...  1960
# 1       Bangladesh  Merchandise exports to low- and middle-income ...  1960
# 2       Bangladesh  Medium and high-tech exports (% manufactured e...  1960
# 3       Bangladesh  Merchandise imports from low- and middle-incom...  1960
# 4       Bangladesh  Tariff rate, applied, simple mean, primary pro...  1960
# ...            ...                                                ...   ...
# 87469   Bangladesh  Foreign direct investment, net inflows (BoP, c...  2020
# 87470   Bangladesh            Net secondary income (BoP, current US$)  2020
# 87471   Bangladesh     Transport services (% of service imports, BoP)  2020
# 87472   Bangladesh  Agricultural machinery, tractors per 100 sq. k...  2020
# 87473   Bangladesh                  Arable land (hectares per person)  2020
#
#        value
# 0        NaN
# 1        NaN
# ...

# %%
sdf.isnull().sum()
# Out:
# Country Name          0
# Indicator Name        0
# year                  0
# value             49419
# dtype: int64

# %%
sdf.dropna(inplace=True)

# %%
sdf.isnull().sum()
# Out:
# Country Name      0
# Indicator Name    0
# year              0
# value             0
# dtype: int64

# %%
sdf.shape
# Out:
# (38055, 4)

# %%
sdf['Indicator Name'].value_counts()
# Out:
# Gross domestic savings (% of GDP)                                                                                         60
# Population ages 10-14, male (% of male population)                                                                        60
# Population ages 15-64, male (% of male population)                                                                        60
# Population ages 0-14, total                                                                                               60
# Services, value added (current LCU)                                                                                       60
#                                                                                                                           ..
# GHG net emissions/removals by LUCF (Mt of CO2 equivalent)                                                                  1
# ...

# %%
sdf['Indicator Name'].unique()
# Out:
# array(['Population, female', 'Population ages 65 and above, total',
#        'Population ages 40-44, female (% of female population)', ...,
#        'Bird species, threatened', 'Fish species, threatened',
#        'Ease of doing business index (1=most business-friendly regulations)'],
#       dtype=object)
